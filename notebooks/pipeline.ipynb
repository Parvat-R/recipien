# %%
# %run "./00 setup.ipynb"
# Out:
# ...
# Writing dataframe to table...
# Table already exists so skipping...
# Setup done. Table named 'recipe' was created at database 'postgres' at localhost:5432 under the username 'postgres'.

# %%
# %run "./01 ingredients.ipynb"
# Out:
# Done!
# Reading recipe table...
# Loaded 2,230,569 rows
# Parsing NER...
# Writing to ingredients table...
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_3700\1930648623.py:9
#       5 with psycopg.connect(DB_URI) as conn:
#       6     with conn.cursor() as cur:
#       7         for batch_start in range(0, total, BATCH_SIZE):
#       8             batch = df.slice(batch_start, BATCH_SIZE).to_dicts()
# ----> 9             with cur.copy(
#      10                 "COPY ingredients (id, ingredients) FROM STDIN"
#      11             ) as copy:
#      12                 for row in batch:
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\contextlib.py:148, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     146 if typ is None:
#     147     try:
# --> 148         next(self.gen)
#     149     except StopIteration:
# ...
