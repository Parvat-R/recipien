# %% [markdown]
# ## Install the requirements

# %%
# !pip install -r ../requirements.txt

# %% [markdown]
# ## Dataset Init

# %%
import os
if not os.path.exists('../dataset/RecipeNLG_dataset.csv'):
    import kagglehub
    
    # Download latest version
    path = kagglehub.dataset_download(
        "paultimothymooney/recipenlg",
        output_dir="../dataset"
    )
    
    print("Path to dataset files:", path)
else:
    path = "../dataset"

# %% [markdown]
# ## Dataset Pre Processing

# %%
import polars

df: polars.DataFrame = polars.read_csv(path + "/RecipeNLG_dataset.csv")

# %%
df = df.drop_nulls()
df = df.rename({df.columns[0]: "id"})
df.count()
# Out:
# shape: (1, 7)
# ┌─────────┬─────────┬─────────────┬────────────┬─────────┬─────────┬─────────┐
# │ id      ┆ title   ┆ ingredients ┆ directions ┆ link    ┆ source  ┆ NER     │
# │ ---     ┆ ---     ┆ ---         ┆ ---        ┆ ---     ┆ ---     ┆ ---     │
# │ u32     ┆ u32     ┆ u32         ┆ u32        ┆ u32     ┆ u32     ┆ u32     │
# ╞═════════╪═════════╪═════════════╪════════════╪═════════╪═════════╪═════════╡
# │ 2231142 ┆ 2231142 ┆ 2231142     ┆ 2231142    ┆ 2231142 ┆ 2231142 ┆ 2231142 │
# └─────────┴─────────┴─────────────┴────────────┴─────────┴─────────┴─────────┘

# %% [markdown]
# ## Database to Postgres

# %%
import psycopg
import os
from dotenv import load_dotenv

load_dotenv("../.env")  # Load DB_URI from .env file if present
DB_URI = os.getenv("DB_URI", "postgresql://postgres:root@localhost:5432/postgres")

# %%
try:
    print("Writing dataframe to table...")
    df.write_database('recipe', DB_URI, engine="adbc", if_table_exists='fail')
    print("Table written!")
except Exception as e:
    print("Table already exists so skipping...")
# Out:
# Writing dataframe to table...
# Table already exists so skipping...

# %%
print("Setup done. Table named 'recipe' was created at database 'postgres' at localhost:5432 under the username 'postgres'.")
# Out:
# Setup done. Table named 'recipe' was created at database 'postgres' at localhost:5432 under the username 'postgres'.
